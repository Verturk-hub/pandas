# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61aa085f-5871-4fe3-9b42-be6f21798763" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61aa085f-5871-4fe3-9b42-be6f21798763">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Automobile_data.csv to Automobile_data.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['Automobile_data.csv']))
df.head()
# Out:
#    index      company   body-style  ...  horsepower  average-mileage    price
# 0      0  alfa-romero  convertible  ...         111               21  13495.0
# 1      1  alfa-romero  convertible  ...         111               21  16500.0
# 2      2  alfa-romero    hatchback  ...         154               19  16500.0
# 3      3         audi        sedan  ...         102               24  13950.0
# 4      4         audi        sedan  ...         115               18  17450.0
#
# [5 rows x 10 columns]

# %%
df.tail()
# Out:
#     index     company body-style  ...  horsepower  average-mileage    price
# 56     81  volkswagen      sedan  ...          85               27   7975.0
# 57     82  volkswagen      sedan  ...          52               37   7995.0
# 58     86  volkswagen      sedan  ...         100               26   9995.0
# 59     87       volvo      sedan  ...         114               23  12940.0
# 60     88       volvo      wagon  ...         114               23  13415.0
#
# [5 rows x 10 columns]

# %%
print(df[['company','price']][df['price'] == df['price'].max()])
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
company = df.groupby('company')
toyota = company.get_group('toyota')
toyota
# Out:
#     index company body-style  ...  horsepower  average-mileage    price
# 48     66  toyota  hatchback  ...          62               35   5348.0
# 49     67  toyota  hatchback  ...          62               31   6338.0
# 50     68  toyota  hatchback  ...          62               31   6488.0
# 51     69  toyota      wagon  ...          62               31   6918.0
# 52     70  toyota      wagon  ...          62               27   7898.0
# 53     71  toyota      wagon  ...          62               27   8778.0
# 54     79  toyota      wagon  ...         156               19  15750.0
#
# [7 rows x 10 columns]

# %%
df['company'].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
company['company','price'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      company    price
# company
# alfa-romero      alfa-romero  16500.0
# audi                    audi  18920.0
# bmw                      bmw  41315.0
# chevrolet          chevrolet   6575.0
# dodge                  dodge   6377.0
# honda                  honda  12945.0
# isuzu                  isuzu   6785.0
# jaguar                jaguar  36000.0
# mazda                  mazda  18344.0
# mercedes-benz  mercedes-benz  45400.0
# mitsubishi        mitsubishi   8189.0
# nissan                nissan  13499.0
# porsche              porsche  37028.0
# toyota                toyota  15750.0
# volkswagen        volkswagen   9995.0
# volvo                  volvo  13415.0

# %%
company['company','average-mileage'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                average-mileage
# company
# alfa-romero          20.333333
# audi                 20.000000
# bmw                  19.000000
# chevrolet            41.000000
# dodge                31.000000
# honda                26.333333
# isuzu                33.333333
# jaguar               14.333333
# mazda                28.000000
# mercedes-benz        18.000000
# mitsubishi           29.500000
# nissan               31.400000
# porsche              17.000000
# toyota               28.714286
# volkswagen           31.750000
# volvo                23.000000

# %%
dfsorted = df.sort_values(by=['price'])
dfsorted.head(5)
# Out:
#     index     company body-style  ...  horsepower  average-mileage   price
# 13     16   chevrolet  hatchback  ...          48               47  5151.0
# 27     36       mazda  hatchback  ...          68               30  5195.0
# 48     66      toyota  hatchback  ...          62               35  5348.0
# 36     49  mitsubishi  hatchback  ...          68               37  5389.0
# 28     37       mazda  hatchback  ...          68               31  6095.0
#
# [5 rows x 10 columns]

# %%
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
dfGerman = pd.DataFrame.from_dict(GermanCars)
JapaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
dfJapanese = pd.DataFrame.from_dict(JapaneseCars)
carsdf = pd.concat([dfGerman,dfJapanese], keys=['Germany','Japan'])
carsdf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %%
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
dfPrice = pd.DataFrame.from_dict(Car_Price)
Car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
dfHorse = pd.DataFrame.from_dict(Car_Horsepower)
pd.merge(dfPrice,dfHorse, on='Company')
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
